# %% [markdown]
# # **Object-Oriented Programming (OOP)**

# %% [markdown]
# ## CLASS AND OBJECTS IN PYTHON
# Python is an object oriented programming language.
#
# Almost everything in Python is an object, with its properties and methods.
#
# A Class is like an object constructor, or a "blueprint" for creating objects.

# %% [markdown]
# # Primary goal of Object-Oriented Programming (OOP)
#
# Object Oriented programming language is based on classes and objects.
# It is used to structure a program into a simple, reusable piece of code. The entire software program runs by having multiple objects interact with objects to create large programs.
#
# **Goals** of object-oriented programming language :
#
# **Adaptability** - means the software may run on different generations and grows over a long lifetime.
#
# To **reuse** the code in which child classes uses the properties of the base class.
#
# To hold entire data into a single object such that it would be easy to pass this to other methods and objects.
#
# Multiprocessing is also in object-oriented programming.
#
# Binding of data to avoid data loss.
#
# **Robustness** - it means complex programs should operate correctly.
#
# The three primary goals of Object Oriented Programming are Robustness, Adaptability, and Reusability.

# %% [markdown]
# # **Object in Python**
#
# Objects are the instances of a particular class. Objects are different copies of the class with some actual values.An Object is an instance of a Class. A class is like a blueprint while an instance is a copy of the class with actual values. Python is an object-oriented programming language that stresses objects i.e. it mainly emphasizes functions.
#
# An object is called an instance of a class. For example, suppose Bike is a class then we can create objects like bike1, bike2, etc from the class. Everything is in Python treated as an object, including variable, function, list, tuple, dictionary, set, etc. Every object belongs to its class. For example - An integer variable belongs to integer class. An object is a real-life entity. An object is the collection of various data and functions that operate on those data. An object contains the following properties:
#
# **State-** The attributes of an object represents its state. It also reflects the properties of an object.
#
# **Behavior**- The method of an object represents its behavior.
#
# **Identity**- Each object must be uniquely identified and allow interacting with the other objects.

# %% [markdown]
# # **Class in Python**
# Class is a blueprint which defines some properties and behaviors. A class is a code template for creating objects. An object is an instance of a class which has those properties and behaviours attached. A class is not allocated memory when it is defined. An object is allocated memory when it is created. Class is a logical entity whereas objects are physical entities.Classes provide a means of bundling data and functionality together. Creating a new class creates a new type of object, allowing new instances of that type to be made.In Python, a class is a user-defined data type that contains both the data itself and the methods that may be used to manipulate it. In a sense, classes serve as a template to create objects. They provide the characteristics and operations that the objects will employ.
#
# Suppose a class is a prototype of a building. A building contains all the details about the floor, rooms, doors, windows, etc. we can make as many buildings as we want, based on these details. Hence, the building can be seen as a class, and we can create as many objects of this class.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ref:https://pynative.com/python-classes-and-objects/

# %% [markdown]
# # **Attributes and methods in a class**
#
# ## i) Class Attributes
# In Class, attributes can be defined into two parts:
#
# **Instance variables:** The instance variables are attributes attached to an instance of a class. We define instance variables in the constructor ( the init() method of a class).
#
#
# **Class Variables:** A class variable is a variable that is declared inside of class, but outside of any instance method or init() method.
# Objects do not share instance attributes. Instead, every object has its copy of the instance attribute and is unique to each object.
#
# All instances of a class share the class variables. However, unlike instance variables, the value of a class variable is not varied from object to object.
#
# Only one copy of the static variable will be created and shared between all objects of the class.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ref:https://pynative.com/python-classes-and-objects/

# %% [markdown]
# ### Accessing properties and assigning values
#
#
# An instance attribute can be accessed or modified by using the dot notation:
#
#                    instance_name.attribute_name.
#
#
# A class variable is accessed or modified using the class name
#
#                    class_name.attribute_name.

# %% [markdown]
# # ii)  Class Methods
#
#
# In Object-oriented programming, Inside a Class, we can define the following three types of methods.
#
#
# **Instance method:**  Used to access or modify the object state. If we use instance variables inside a method, such methods are called instance methods.
#
# **Class method:**  Used to access or modify the class state. In method implementation, if we use only class variables, then such type of methods we should declare as a class method.
#
# **Static method:**  It is a general utility method that performs a task in isolation. Inside this method, we don’t use instance or class variable because this static method doesn’t have access to the class attributes.

# %% [markdown]
# # **Instance variable versus Class variables **
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Self parameter in Python class methods**
#
# The self parameter is a reference to the current instance of the class, and is used to access variables that belongs to the class.
#
# It does not have to be named self , you can call it whatever you like, but it has to be the first parameter of any function in the class

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  #method 1
  def display(self):
    print(f"my name is {self.name} and age is {self.age}")

# %%
class Person:
  def __init__(abc, name, age):    #using abc instead of self but it should be the first argument
    abc.name = name
    abc.age = age

  def display(xyz):                 #using xyz instead of self but it should be the first argument
    print("Hello my name is " + xyz.name)

p1 = Person("John", 36)
p1.display()

# %% [markdown]
# ## **The pass Statement**
# class definitions cannot be empty, but if you for some reason have a class definition with no content, put in the pass statement to avoid getting an error.

# %%
#Empty class

class Person:
        pass

# %% [markdown]
# # **Create Object**

# %%
#Creating object of a class
person1 = Person()
print(type(person1))
print(type(Person))
# Out:
# <class '__main__.Person'>
# <class 'type'>

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  #method 1
  def display(self):
    print(f"my name is {self.name} and age is {self.age}")

  #method 2
  def myfunc(self):
    print("Hello my name is " + self.name)

p1 = Person("Martin", 36)
p1.display()

# %% [markdown]
# # **dir()**
# The dir() function in python is an inbuilt function used on an object to look at all the properties / attributes and methods of that object, without its values (if any)

# %%
dir(person1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %% [markdown]
# # The __init__() Function
# Use the __init__() function to assign values to object properties, or other operations that are necessary to do when the object is being created:

# %%
#str is the default functionality that print object information of the class
#init is the constructor
#Note: The __init__() function is called automatically every time the class is being used to create a new object.

# %% [markdown]
# Create a class named Person, use the __init__() function to assign values for first name and last name:

# %%
class Person:
  def __init__(self,name1,last_name1):
    self.name=name1
    self.last_name=last_name1

# %%
person1 = Person("Thasni","T")
print(person1.name)
print(person1.last_name)
print(person1)
# Out:
# Thasni
# T
# ...

# %% [markdown]
# # The __str__() Function
# The __str__() function controls what should be returned when the class object is represented as a string.
#
# If the __str__() function is not set, the string representation of the object is returned:

# %%
#The string representation of an object WITHOUT the __str__() function:
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("Martin", 36)

print(p1)

# %%
#The string representation of an object WITH the __str__() function:
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def __str__(self):
    return f"{self.name}({self.age})"

p1 = Person("Martin", 36)

print(p1)
# Out:
# Martin(36)

# %% [markdown]
# # **Delete Object Properties**
#
# You can delete properties on objects by using the del keyword:
#
# #**Delete Objects**
#
# You can delete objects by using the del keyword:

# %%
del p1.name    #Deleting the object property name

# %%
dir(p1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'display']

# %%
del p1.age

# %%
dir(p1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'display']

# %%
del p1        #Deleting the object itself

# %% [markdown]
# # Q1. Create a bank account with properties
#
#
# # 1.   Account number
# # 2.   Account Holder
# # 3.   Balance
#
# # Write functions to withdraw and  deposit money and also define a function to dispaly the balance

# %%
    #Bank account
class BankAccount:
     def __init__(self,account_number,account_holder,balance=0):
        self.account_number=account_number
        self.account_holder=account_holder
        self.balance=balance

     #Function 1
     def deposit(self,deposit):
        self.balance+=deposit

     #Function 2
     def withdrawl(self,withdraw):
        if withdraw <= self.balance:
           self.balance-=withdraw
        else:
          print("Balance is less")

# %%
account1=BankAccount("1234","John",0)
print(account1.balance)
# Out:
# 0

# %%
account1.deposit(100)
print(account1.balance)
# Out:
# 100

# %%
account1.withdrawl(50)
print(account1.balance)
# Out:
# Balance is less
# 0

# %% [markdown]
# # Q2. Create a TODOLIST with following attributes ,
#
#
# # 1.   Owner
#
# # 2.   Tasks
#
# # Write funtions to add new tasks ,remove competed task and display the tasks

# %%
#class  representing to do list
class Todolist:
  ##constructor
   def __init__(self,owner):
      self.owner=owner
      self.tasks=[]

   def add_task(self,task):
       self.tasks.append(task)

   def complete_task(self,task):
    if task in self.tasks:
      self.tasks.remove(task)
      print(f"Task '{task}' completed")
    else:
      print("The task is not found")

   def display_tasks(self):
    print(f"The to do task of {self.owner}:")
    for task in self.tasks:
      print(task)

# %%
thasni=Todolist("Thasni")
thasni.tasks
thasni.add_task("I have to teach at 9 am ")
thasni.display_tasks()
thasni.add_task("12 pm Lunch ")
thasni.display_tasks()
thasni.complete_task("I have to teach at 9 am ")
thasni.display_tasks()
# Out:
# The to do task of Thasni:
# I have to teach at 9 am with real world examples
# The to do task of Thasni:
# I have to teach at 9 am with real world examples
# 12 pm Lunch
# Task 'I have to teach at 9 am with real world examples' completed
# The to do task of Thasni:
# 12 pm Lunch

# %%
class BankAccount:
  def __init__(thasni,account_number1,account_holder1,balance1=0):
    thasni.account_number=account_number1
    thasni.account_holder=account_holder1
    thasni.balance=balance1

  def deposit(thasni,amount):
    thasni.balance+=amount

  def withdraw(self,amount):
    if amount <= self.balance:
      self.balance-=amount
    else:
      print("Insufficient balance")

# %%
person1=BankAccount(1234,"Thasni T")

# %%
person1.deposit(100)
print(person1.balance)
# Out:
# 300

# %%
person1.withdraw(100)
print(person1.balance)
# Out:
# insufficient balance
# 0

# %% [markdown]
# # Q3. Create a class CAR  with following attributes ,
#
#
#   # 1.   Brand
#   # 2.   Model
#   # 3.   Color
#
# # Write funtions to print messages to start and stop the engine

# %%
class Car:
  def __init__(self,brand,model,color):
    self.brand =brand
    self.model=model
    self.color=color

  def start_engine(self):
    print(f"The {self.color} {self.brand} {self.model} is starting")

  def stop_engine(self):
    print(f"The {self.color} {self.brand} {self.model} is stopping")

# %%
car1=Car("BMW","EV","Red")

# %%
car1.brand
# Out:
# 'BMW'

# %% [markdown]
# # Q4. Create a class Mobile Phone with following attributes ,
#
# # 1.   Brand
# # 2.   Model
# # 3.   Processor
# # 4.   Price
#
# # Write funtions to print messages to make calls,send messages and to end call

# %%
class Mobilephone:
  def __init__(self,brand,model,processor,price):
    self.brand=brand
    self.model=model
    self.processor=processor
    self.price=price


  def makecalls(self,number):
    print(f"I am making call to {number } with {self.brand} and  {self.model} ")

  def sendmessages(self,number,message):
    print(f"I am sending message {message} to {number} from {self.model} and {self.brand}")

  def endcall(self,number ):
    print(f"Call is disconnected with {number}")

# %%
mobile1=Mobilephone("Samsung","Note 3","8 gen 2", 125000)

mobile1.makecalls(8945435345)
# Out:
# I am making call to 8945435345 with Samsung and  Note 3

# %%
mobile1.sendmessages(84534857345,"Hai")
# Out:
# I am sending message Hai to 84534857345 from Note 3 and Samsung

# %%
mobile1.endcall(457346574657)
# Out:
# Call is disconnected with 457346574657

# %% [markdown]
# # Q5. Create a class Laptop with following attributes ,
#
# # 1.   Model
# # 2.   Brand
# # 3.   RAM
#
# # Write funtions to print messages to switch on and off the phone

# %%
class Laptop:
  def __init__(self,Model,Brand,RAM):
    self.model=Model
    self.brand=Brand
    self.ram=RAM

  def Poweron(self):
    print(f"Switch on the {self.model}")

  def Poweroff(self):
    print(f"Switch off the {self.model}")

# %%
lp=Laptop("ASUS","dhbchgd",512)

# %%
lp.Poweron()
# Out:
# Switch on the ASUS

# %%
#VLC Media Player
#Camera
##Games
#Dishwasher
#Washing Machine

# %% [markdown]
# # Q6.Create a class VLC Media Player with following attributes ,
#
# # 1.   Songs
# # 2.   Movies
#
# # Write funtions to print messages to play audio and video

# %%
class VMplayer:
  def __init__(self,audio,video):
    self.audio=audio
    self.video=video

  def playsong(self):
    print(f"I am playing the song {self.audio}")

  def playvideo(self):
    print(f"I am playing the song {self.video}")

# %%
vm1=VMplayer("Audio1","Video1")
vm1.playsong()
# Out:
# I am playing the song Audio1

# %%
vm1.playvideo()
# Out:
# I am playing the song Video1

# %%
#CAMERA


class camera:
  def __init__(self,model,price):
    self.model=model
    self.price=price

  def display(self):
    print(f"I like the camera model {self.model} having the price  {self.price}")

# %%
cm1=camera("M1",5000)
cm1.display()
# Out:
# I like the camera model M1 having the price  5000

# %%
#Games
class games:
  def __init__(self,name ,score):
    self.name =name
    self.score=score

  def display(self):
    print(f"I scored  {self.score  } scores in the game  {self.name}")

# %%
gm1=games("Tic tac toe", 50)
gm1.display()
# Out:
# I scored  50 scores in the game  Tic tac toe

# %%
#Dishwasher
class dishwash:
  def __init__(self,vessels ,time ):
    self.vessels =vessels
    self.time=time

  def display(self):
    print(f"I washed {self.vessels} vessels in my dishwasher in {self.time} hours")

# %%
dw=dishwash(20,3)
dw.display()
# Out:
# I washed 20 vessels in my dishwasher in 3 hours

# %%
#Washing Machine

class washmachine:
  def __init__(self,load,brand,type1):
    self.load=load
    self.brand=brand
    self.type1=type1

  def display(self):
    print(f"My washing machine is {self.load} and {self.type1} of {self.brand} brand ")

# %%
wm = washmachine("Top Load","Bosch","Fully Automatic")
wm.display()
# Out:
# My washing machine is Top Load and Fully Automatic of Bosch brand

# %% [markdown]
# # **Python Built in Functions**

# %%
#Built in functions
class P:
  pass
obj =P()
dir(obj)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %% [markdown]
# # **Python Built in Functions**

# %% [markdown]
# 1.
# # 1.  '__delattr__',
#
# Definition and Usage
#
# The delattr() function will delete the specified attribute from the specified object.
#
# Syntax
#
# delattr(object, attribute)

# %%
#Delete the "age" property from the "person" object:

class Person:
  name = "Martin"
  age = 36
  country = "India"

delattr(Person, 'age')

# %% [markdown]
# # 2. dict()
#
# The dict() function creates a dictionary.
#
# A dictionary is a collection which is unordered, changeable and indexed.
#
# Create a dictionary containing personal information:

# %%
x = dict(name = "John", age = 36, country = "Norway")

# %% [markdown]
# # 3.dir()
#
# The dir() function returns all properties and methods of the specified object, without the values.
#
# This function will return all the properties and methods, even built-in properties which are default for all object.

# %%
class Person:
  name = "John"
  age = 36
  country = "Norway"

print(dir(Person))

# %% [markdown]
# # 4. __doc__
# Python objects have an attribute called __doc__ that provides a documentation of the object.

# %%
class Person:
    ''' Documentation of the object '''
    pass

print(Person.__doc__)
# Out:
#  Documentation of the object

# %% [markdown]
# # 5. eq
#
# The __eq__ method in Python is used to define how objects of a class are compared for equality. The __eq__ method takes two arguments: self(object on the left-hand side of == operator ) and other(object on the right-hand side of == operator). __eq__ method always returns a boolean value(True or False)

# %%
'''Example
In the below example, we create a class named Person which has two attributes namely name and age.
We then define the __eq__() method in the class to compare the name and age attributes of the person object.
Finally, two instances of the person class are created i.e p1 and p2 and they are compared using the == operator.'''


class Person:
   def __init__(self, name, age):
      self.name = name
      self.age = age

   def __eq__(self, other):
      if isinstance(other, Person):
         return self.name == other.name and self.age == other.age
      return False

p1 = Person("John", 30)
p2 = Person("John", 30)
if p1 == p2:
   print("p1 and p2 are equal")

# %% [markdown]
# # 6. format()
#
# The format() function formats a specified value into a specified format.
#
#
# A value of any format
#
# The format you want to format the value into.
#
# Legal values:
#
# '<' - Left aligns the result (within the available space)
#
# '>' - Right aligns the result (within the available space)
#
# '^' - Center aligns the result (within the available space)
#
# '=' - Places the sign to the left most position
#
# '+' - Use a plus sign to indicate if the result is positive or negative
#
# '-' - Use a minus sign for negative values only
#
# ' ' - Use a leading space for positive numbers
#
# ',' - Use a comma as a thousand separator
#
# '_' - Use a underscore as a thousand separator
#
# 'b' - Binary format
#
# 'c' - Converts the value into the corresponding unicode character
#
# 'd' - Decimal format
#
# 'e' - Scientific format, with a lower case e
#
# 'E' - Scientific format, with an upper case E
#
# 'f' - Fix point number format
#
# 'F' - Fix point number format, upper case
#
# 'g' - General format
#
# 'G' - General format (using a upper case E for scientific notations)
#
# 'o' - Octal format
#
# 'x' - Hex format, lower case
#
# 'X' - Hex format, upper case
#
# 'n' - Number format
#
# '%' - Percentage format

# %%
x = format(255, 'x')
print(x)

y = format(0.5, '%')
print(y)
# Out:
# ff
# 50.000000%

# %% [markdown]
# # 7. ge
#
# To use the greater than or equal to operator on custom objects, define the __ge__() “dunder” magic method that takes two arguments: self and other. You can then use attributes of the custom objects to determine if one is greater than or equal to the other.
#
# The method should return a Boolean True or False — however, this is not required because every object can be automatically converted to a Boolean value using the built-in bool() function.

# %%
class Person:
    def __init__(self, age):
        self.age = age
    def __ge__(self, other):
        return self.age >= other.age
alice = Person(18)
bob = Person(17)
carl = Person(18)
print(alice >= bob)
# True
print(alice >= carl)
# True
print(bob >= alice)
# False
# Out:
# True
# True
# False

# %% [markdown]
# # 8. getattr()
#
# The getattr() function returns the value of the specified attribute from the specified object.

# %%
#Use the "default" parameter to write a message when the attribute does not exist:

class Person:
  name = "John"
  age = 36
  country = "Norway"

x = getattr(Person, 'page', 'my message')
print(x)
# Out:
# my message

# %%
#Get the value of the "age" property of the "Person" object:

class Person:
  name = "John"
  age = 36
  country = "Norway"

x = getattr(Person, 'age')
print(x)
# Out:
# 36

# %% [markdown]
# # 9.The __gt__ method
#
#
# The __gt__ method  is the implementation of   >

# %% [markdown]
# # 10. hash()
#
# Python has a built-in hash() function that returns the hash value of an object. This makes creating the hash of an object quite simple in Python.

# %% [markdown]
# # 11. __init_subclass__(cls)
#
# The Python class.__init_subclass__(cls) method is called on a given class each time a subclass cls for that class is created.

# %% [markdown]
# # 12.  __le__(y)
#
# __le__(y) to obtain a return value when comparing two objects using x <= y .

# %% [markdown]
# # 13. __lt__
#
# __lt__  magic method is one magic method that is used to define or implement the functionality of the less than operator “<”

# %% [markdown]
# # 14.Reduce
#
# The reduce() function is defined in functools module in Python. It accepts two arguments, a function and an iterable, and returns a single value.

# %% [markdown]
# # 15.Reduce_ex
#
# The large data objects to be pickled must implement a __reduce_ex__() method specialized for protocol 5 and higher

# %% [markdown]
# # 16.Repr
#
#
#  __repr__ is a special method used to represent a class's objects as a string. __repr__ is called by the repr() built-in function.
#
#   You can define your own string representation of your class objects using the __repr__ method.
#
#   Special methods are a set of predefined methods used to enrich your classes.
#
#   Returns a readable version of an object

# %% [markdown]
# # 17. setattr
#
# The setattr() function sets the value of the specified attribute of the specified object.

# %% [markdown]
# # 18. Sizeof
#
#
# The __sizeof__() operator returns the size of the object without any extra overhead for garbage collection.

# %% [markdown]
# # 19.str
#
# The str() function converts the specified value into a string.

# %% [markdown]
# # 20.  subclass hook
#
# __subclasshook__ check whether subclass is considered a subclass of some ABC. This means that you can customize the behavior of issubclass ...

# %% [markdown]
# # 21.weakref
#
# The module allows Python programmer to create weak reference to objects. A weak reference is a reference that does not protect the object from getting garbage collected
